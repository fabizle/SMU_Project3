# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the data and check first five roads
df = pd.read_csv("Resources/tornados.csv")
df.head()
# Out:
#     om    yr  mo  dy        date      time               tz  \
# 0  192  1950  10   1  1950-10-01  21:00:00  America/Chicago
# 1  193  1950  10   9  1950-10-09  02:15:00  America/Chicago
# 2  195  1950  11  20  1950-11-20  02:20:00  America/Chicago
# 3  196  1950  11  20  1950-11-20  04:00:00  America/Chicago
# 4  197  1950  11  20  1950-11-20  07:30:00  America/Chicago
#
#            datetime_utc  st  stf  ...   elon   len  wid  ns  sn   f1  f2  f3  \
# 0  1950-10-02T03:00:00Z  OK   40  ... -102.3  15.8   10   1   1   25   0   0
# 1  1950-10-09T08:15:00Z  NC   37  ...    0.0   2.0  880   1   1   47   0   0
# 2  1950-11-20T08:20:00Z  KY   21  ...    0.0   0.1   10   1   1  177   0   0
# 3  1950-11-20T10:00:00Z  KY   21  ...    0.0   0.1   10   1   1  209   0   0
# 4  1950-11-20T13:30:00Z  MS   28  ...    0.0   2.0   37   1   1  101   0   0
#
#    f4     fc
# 0   0  False
# 1   0  False
# 2   0  False
# 3   0  False
# 4   0  False
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (68693, 27)

# %%
# Check data type and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68693 entries, 0 to 68692
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   om            68693 non-null  int64
#  1   yr            68693 non-null  int64
#  2   mo            68693 non-null  int64
#  3   dy            68693 non-null  int64
#  4   date          68693 non-null  object
#  5   time          68693 non-null  object
#  6   tz            68693 non-null  object
#  7   datetime_utc  68693 non-null  object
#  8   st            68693 non-null  object
#  9   stf           68693 non-null  int64
#  10  mag           67937 non-null  float64
#  11  inj           68693 non-null  int64
#  12  fat           68693 non-null  int64
#  13  loss          41523 non-null  float64
#  14  slat          68693 non-null  float64
#  15  slon          68693 non-null  float64
#  16  elat          68693 non-null  float64
#  17  elon          68693 non-null  float64
# ...

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 1

# %%
# Drop duplicate row
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Check missing values by column
df.isna().sum()
# Out:
# om                  0
# yr                  0
# mo                  0
# dy                  0
# date                0
# time                0
# tz                  0
# datetime_utc        0
# st                  0
# stf                 0
# mag               756
# inj                 0
# fat                 0
# loss            27170
# slat                0
# slon                0
# elat                0
# elon                0
# len                 0
# wid                 0
# ns                  0
# sn                  0
# f1                  0
# f2                  0
# f3                  0
# f4                  0
# fc                  0
# dtype: int64

# %%
# Check the missing values for'mag'
df["mag"].value_counts(dropna = False)
# Out:
# mag
# 0.0    31772
# 1.0    23328
# 2.0     9636
# 3.0     2556
# NaN      756
# 4.0      585
# 5.0       59
# Name: count, dtype: int64

# %%
# Drop rows with missing values
df.dropna(inplace=True)

# %%
df['mag'].isnull().sum()
# Out:
# 0

# %%
df['loss'].isnull().sum()
# Out:
# 0

# %%
# Another check missing values by column
df.isna().sum()
# Out:
# om              0
# yr              0
# mo              0
# dy              0
# date            0
# time            0
# tz              0
# datetime_utc    0
# st              0
# stf             0
# mag             0
# inj             0
# fat             0
# loss            0
# slat            0
# slon            0
# elat            0
# elon            0
# len             0
# wid             0
# ns              0
# sn              0
# f1              0
# f2              0
# f3              0
# f4              0
# fc              0
# dtype: int64

# %%
df["st"].unique()
# Out:
# array(['OK', 'NC', 'KY', 'MS', 'PA', 'IL', 'AR', 'MO', 'OH', 'TX', 'LA',
#        'TN', 'FL', 'AL', 'SC', 'KS', 'WY', 'NE', 'GA', 'IA', 'SD', 'ND',
#        'MN', 'WI', 'NM', 'CT', 'IN', 'MD', 'CO', 'VA', 'OR', 'CA', 'NJ',
#        'MI', 'MA', 'NH', 'NY', 'MT', 'VT', 'ME', 'ID', 'UT', 'WA', 'DE',
#        'HI', 'AZ', 'WV', 'AK', 'PR', 'NV', 'RI', 'DC'], dtype=object)

# %%
df.st.value_counts().plot(kind='bar', color=sns.color_palette('crest'), figsize=(10, 7))
plt.ylabel("Count")
plt.xlabel("State")
plt.title("Number of Tornadoes by State")
# Out:
# Text(0.5, 1.0, 'Number of Tornadoes by State')

# %%
# Plot tornados by year and magnitude
data= df.groupby(["st", "mag"])["st"].count().reset_index(name = 'Count')
plt.figure(figsize = (18, 8)) 
sns.lineplot(data=data, x="st", y="Count", hue='mag', marker="o", palette = 'crest')
plt.title("Tornado Magnitudes by State")
plt.xlabel("State")
plt.ylabel("Count")
plt.show()
